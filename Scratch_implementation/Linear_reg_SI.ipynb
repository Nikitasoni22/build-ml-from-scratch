# %%
import numpy as np

# %%
#Linear regression

class LinearRegression:
    def __init__(self,learning_rate=0.01,n_iter=1000):
        self.bias=None
        self.weight=None
        self.lr=learning_rate
        self.n_iter=n_iter


    def fit(self,X,y):
        m,n=X.shape #(no of samples, no. of features)
        
        #step 1
        self.bias=0
        self.weight=np.zeros(n)

        for i in range(self.n_iter):
             #step 2
            y_pred=self.bias + np.dot(X,self.weight)
            #step 3
            db=(1/m)* np.sum(y_pred -y)
            dw=(1/m)*np.dot(X.T , (y_pred-y))
            #step 4
            self.bias=self.bias - self.lr *db
            self.weight=self.weight - self.lr *dw 
        
    def predict(self,X):
        y_pred =self.bias + np.dot(X,self.weight)

        return y_pred

# %%
X=np.array([[1],[2],[3],[4],[5]])
y=np.array([2,4,6,8,10])

model=LinearRegression()
model.fit(X,y)

y_pred=model.predict(X)
print(y_pred)
# Out:
# [2.06850809 4.04226297 6.01601785 7.98977273 9.96352761]

# %%
#Linear regression with ordinary least square 

class LinearRegressionOLS:
    def __init__(self):
        self.bias=None
        self.weight=None
    def fit():
        m,n=X.shape()
        X_updated=np.c_[(np.ones(m,1),X)]

        #normal equation

        theta=np.dot(np.linealg.inv(np.dot(X_updated.T,X_updated)),np.dot(X_updated.T,y))

        self.bias=theta[0]
        self.weight=theta[1:]

    def predict(self,X):
        y_pred =self.bias + np.dot(X,self.weight)

        return y_pred

# %%
X=np.array([[1],[2],[3],[4],[5]])
y=np.array([2,4,6,8,10])

model=LinearRegression()
model.fit(X,y)

y_pred=model.predict(X)
print(y_pred)
# Out:
# [2.06850809 4.04226297 6.01601785 7.98977273 9.96352761]
